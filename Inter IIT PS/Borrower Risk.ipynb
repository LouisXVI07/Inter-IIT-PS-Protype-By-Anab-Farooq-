# %%
# !pip install -q numpy==1.26.4 pandas scikit-learn tqdm \
sentence-transformers transformers langchain chromadb matplotlib seaborn
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 4.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 96.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.7/20.7 MB 84.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 17.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 72.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.3/103.3 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 31.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.3/132.3 kB 7.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.9/65.9 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.0/208.0 kB 12.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 517.7/517.7 kB 25.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.4/128.4 kB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 89.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 456.8/456.8 kB 26.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 5.8 MB/s eta 0:00:00
#   Building wheel for pypika (pyproject.toml) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# pytensor 2.35.1 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# google-adk 1.16.0 requires opentelemetry-api<=1.37.0,>=1.37.0, but you have opentelemetry-api 1.38.0 which is incompatible.
# google-adk 1.16.0 requires opentelemetry-sdk<=1.37.0,>=1.37.0, but you have opentelemetry-sdk 1.38.0 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.37.0 requires opentelemetry-exporter-otlp-proto-common==1.37.0, but you have opentelemetry-exporter-otlp-proto-common 1.38.0 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.37.0 requires opentelemetry-proto==1.37.0, but you have opentelemetry-proto 1.38.0 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.37.0 requires opentelemetry-sdk~=1.37.0, but you have opentelemetry-sdk 1.38.0 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.

# %%
import os
import pickle
import random
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sentence_transformers import SentenceTransformer
from tqdm import tqdm
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, pipeline

# %%
np.random.seed(42)

OUT_DIR = "/mnt/data/risk_prototype_full"
os.makedirs(OUT_DIR, exist_ok=True)

# Borrowers
n_borrowers = 50
borrowers = pd.DataFrame({
    "borrower_id": np.arange(1, n_borrowers+1),
    "name": [f"Borrower_{i}" for i in range(1, n_borrowers+1)],
})
borrowers.to_csv(os.path.join(OUT_DIR, "borrowers.csv"), index=False)

# %%
n_events = 2000
events = pd.DataFrame({
    "event_id": np.arange(1, n_events+1),
    "borrower_id": np.random.choice(borrowers["borrower_id"], n_events),
    "amount": np.random.uniform(50, 1000, n_events),
    "ts": pd.date_range("2025-01-01", periods=n_events, freq="T"),
    # label for testing
    "label": np.random.choice([0,1], n_events, p=[0.85,0.15])
})
events.to_csv(os.path.join(OUT_DIR, "events.csv"), index=False)

print("borrowers.csv and events.csv gen")
# Out:
# borrowers.csv and events.csv gen
# /tmp/ipython-input-3312250610.py:6: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   "ts": pd.date_range("2025-01-01", periods=n_events, freq="T"),

# %%
borrowers = pd.read_csv(os.path.join(OUT_DIR, "borrowers.csv"))


np.random.seed(42)
fs = pd.DataFrame({
    "borrower_id": borrowers["borrower_id"],
    "count": np.random.randint(20, 50, len(borrowers)),
    "sum_amount": np.random.uniform(1000, 5000, len(borrowers)),
})
fs["avg_amount"] = fs["sum_amount"] / fs["count"]
fs["max_amount"] = fs["avg_amount"] + np.random.uniform(10, 50, len(borrowers))
fs["min_amount"] = fs["avg_amount"] - np.random.uniform(5, 30, len(borrowers))
fs["prior_open_default"] = np.random.choice([0,1], len(borrowers), p=[0.85,0.15])
fs.set_index("borrower_id", inplace=True)
fs.to_csv(os.path.join(OUT_DIR, "feature_store.csv"))

# %%
scaler = StandardScaler()
feature_cols = ["avg_amount","max_amount","min_amount","count","prior_open_default"]
scaler.fit(fs[feature_cols].values)
with open(os.path.join(OUT_DIR, "scaler.pkl"), "wb") as f:
    pickle.dump(scaler, f)


X = scaler.transform(fs[feature_cols].values)
y = np.random.choice([0,1], len(fs), p=[0.85,0.15])
model = LogisticRegression()
model.fit(X, y)
with open(os.path.join(OUT_DIR, "model.pkl"), "wb") as f:
    pickle.dump(model, f)

print("Feature store, scaler, and model saved")
# Out:
# Feature store, scaler, and model saved

# %%
fs_path = os.path.join(OUT_DIR, "feature_store.csv")
scaler_path = os.path.join(OUT_DIR, "scaler.pkl")
model_path = os.path.join(OUT_DIR, "model.pkl")
events_path = os.path.join(OUT_DIR, "events.csv")
decision_log_path = os.path.join(OUT_DIR, "decision_log.csv")


fs = pd.read_csv(fs_path).set_index("borrower_id")
with open(scaler_path, "rb") as f: scaler = pickle.load(f)
with open(model_path, "rb") as f: model = pickle.load(f)
events = pd.read_csv(events_path).head(500)

# Policy docs
policy_docs = [
    {"id":"p1","text":"Prior default + high risk → HUMAN_REVIEW"},
    {"id":"p2","text":"Risk>0.8 → FREEZE"},
    {"id":"p3","text":"Amount>500 → VERIFY"},
    {"id":"p4","text":"Risk<0.3 → ALLOW"}
]

# %%
embedder = SentenceTransformer("all-MiniLM-L6-v2")
doc_embeddings = embedder.encode([d["text"] for d in policy_docs], normalize_embeddings=True)

# Local agent LLM
tokenizer = AutoTokenizer.from_pretrained("google/flan-t5-small")
model_lm = AutoModelForSeq2SeqLM.from_pretrained("google/flan-t5-small")
llm_pipe = pipeline("text2text-generation", model=model_lm, tokenizer=tokenizer, device=-1, max_length=128, do_sample=False)

# Retrieval helper
def retrieve_policy(risk_score, borrower_id):
    query = f"risk_score={risk_score:.3f} borrower={borrower_id}"
    q_emb = embedder.encode([query], normalize_embeddings=True)
    sims = np.dot(q_emb, doc_embeddings.T)[0]
    top_idx = sims.argmax()
    return policy_docs[top_idx]["text"]
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/308M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# Device set to use cpu

# %%
decision_log = []

for _, row in tqdm(events.iterrows(), total=len(events)):
    bid = row.borrower_id
    fs_row = fs.loc[bid]
    x_vec = np.array([[fs_row["avg_amount"], fs_row["max_amount"], fs_row["min_amount"],
                       fs_row["count"], fs_row["prior_open_default"]]])
    risk_score = model.predict_proba(scaler.transform(x_vec))[0,1]

    retrieved_doc = retrieve_policy(risk_score, bid)

    prompt = f"""
You are a risk agent. Based on the information, recommend one ACTION from {{FREEZE, VERIFY, ALLOW, HUMAN_REVIEW}}.
Borrower features: {fs_row.to_dict()}
Predicted risk_score: {risk_score:.3f}
Relevant policy document: {retrieved_doc}
Provide ACTION and a one-line REASON grounded in the features or policy.
Format: ACTION: <action>; REASON: <one-line reason>
"""
    output = llm_pipe(prompt)[0]["generated_text"]

    action = "HUMAN_REVIEW"
    if "FREEZE" in output.upper(): action="FREEZE"
    elif "VERIFY" in output.upper(): action="VERIFY"
    elif "ALLOW" in output.upper(): action="ALLOW"
    elif "HUMAN_REVIEW" in output.upper(): action="HUMAN_REVIEW"

    decision_log.append({
        "event_id": row.event_id,
        "borrower_id": bid,
        "amount": row.amount,
        "risk_score": risk_score,
        "retrieved_doc": retrieved_doc,
        "action": action,
        "reason": output
    })

# Save decision log
pd.DataFrame(decision_log).to_csv(decision_log_path, index=False)
print("✅ Step 3 completed: decision log saved")
# Out:
# 100%|██████████| 500/500 [35:18<00:00,  4.24s/it]
# ✅ Step 3 completed: decision log saved

# %%
 decision_log
# Out:
# [{'event_id': 1,
#   'borrower_id': 39,
#   'amount': 168.00896839165637,
#   'risk_score': 0.08288878427458314,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 2,
#   'borrower_id': 29,
#   'amount': 901.4102375507864,
#   'risk_score': 0.07791374846605766,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 3,
#   'borrower_id': 15,
#   'amount': 615.0378055080893,
#   'risk_score': 0.16315945151743974,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 4,
#   'borrower_id': 43,
#   'amount': 635.7743527693503,
#   'risk_score': 0.07371093251209905,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': 'None of the above choices                                                             '},
#  {'event_id': 5,
#   'borrower_id': 8,
#   'amount': 632.2969661223257,
#   'risk_score': 0.10438587777978468,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 6,
#   'borrower_id': 21,
#   'amount': 333.89409202044817,
#   'risk_score': 0.09674263533520072,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': 'None of the above choices                                                             '},
#  {'event_id': 7,
#   'borrower_id': 39,
#   'amount': 938.4417245344866,
#   'risk_score': 0.08288878427458314,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 8,
#   'borrower_id': 19,
#   'amount': 949.9829394994867,
#   'risk_score': 0.10068270906657707,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 9,
#   'borrower_id': 23,
#   'amount': 644.0394272032504,
#   'risk_score': 0.2582170183590636,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 21.0, 'sum_amount': 3270.801311279966, 'avg_amount': 155.7524433942841, 'max_amount': 183.3259034689149, 'min_amount': 149.9261750717704, 'prior_open_default': 0.0"},
#  {'event_id': 10,
#   'borrower_id': 11,
#   'amount': 794.251589644534,
#   'risk_score': 0.24262931599339552,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 11,
#   'borrower_id': 11,
#   'amount': 631.6450865871001,
#   'risk_score': 0.24262931599339552,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 12,
#   'borrower_id': 24,
#   'amount': 510.1785251953386,
#   'risk_score': 0.20904650199164818,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 13,
#   'borrower_id': 36,
#   'amount': 677.7791123842882,
#   'risk_score': 0.14905862430447472,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 31.0, 'sum_amount': 3158.768529556319, 'avg_amount': 101.89575901794578, 'max_amount': 147.1144725785561, 'min_amount': 72.31018049557471, 'prior_open_default': 0.0"},
#  {'event_id': 14,
#   'borrower_id': 40,
#   'amount': 575.3513799623605,
#   'risk_score': 0.08666734902384388,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 15,
#   'borrower_id': 24,
#   'amount': 617.6020695003335,
#   'risk_score': 0.20904650199164818,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 16,
#   'borrower_id': 3,
#   'amount': 794.6409257479188,
#   'risk_score': 0.07171531307422917,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 17,
#   'borrower_id': 22,
#   'amount': 506.8586398765356,
#   'risk_score': 0.23561546304175604,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 18,
#   'borrower_id': 2,
#   'amount': 88.71640078784912,
#   'risk_score': 0.09594517853251398,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 39.0, sum_amount': 4932.923543227153, avg_amount': 126.48521905710648, max_amount': 173.53725419764044, min_amount': 113.86568760315576, prior_open_default': 0.096"},
#  {'event_id': 19,
#   'borrower_id': 24,
#   'amount': 205.7995069400224,
#   'risk_score': 0.20904650199164818,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 20,
#   'borrower_id': 44,
#   'amount': 466.6768556650615,
#   'risk_score': 0.15010566058163563,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 21,
#   'borrower_id': 30,
#   'amount': 738.5852318803554,
#   'risk_score': 0.11010876257857698,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 22,
#   'borrower_id': 38,
#   'amount': 613.6147158946698,
#   'risk_score': 0.1216404509518531,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': 'None of the above choices                                                             '},
#  {'event_id': 23,
#   'borrower_id': 2,
#   'amount': 667.7794765797812,
#   'risk_score': 0.09594517853251398,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 39.0, sum_amount': 4932.923543227153, avg_amount': 126.48521905710648, max_amount': 173.53725419764044, min_amount': 113.86568760315576, prior_open_default': 0.096"},
#  {'event_id': 24,
#   'borrower_id': 21,
#   'amount': 505.3149821474729,
#   'risk_score': 0.09674263533520072,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': 'None of the above choices                                                             '},
#  {'event_id': 25,
#   'borrower_id': 33,
#   'amount': 634.9549208451307,
#   'risk_score': 0.07125389103387866,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 26,
#   'borrower_id': 12,
#   'amount': 362.5665659239291,
#   'risk_score': 0.1102468853321185,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 27,
#   'borrower_id': 22,
#   'amount': 496.6734630618318,
#   'risk_score': 0.23561546304175604,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 28,
#   'borrower_id': 44,
#   'amount': 757.0651123152078,
#   'risk_score': 0.15010566058163563,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 29,
#   'borrower_id': 25,
#   'amount': 878.2411400244652,
#   'risk_score': 0.25778765235851514,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 30,
#   'borrower_id': 49,
#   'amount': 461.9725672585694,
#   'risk_score': 0.06533639659489342,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 31,
#   'borrower_id': 27,
#   'amount': 91.47857482199312,
#   'risk_score': 0.22204469012756772,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 32,
#   'borrower_id': 42,
#   'amount': 203.5889169394625,
#   'risk_score': 0.08054099364550482,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 33,
#   'borrower_id': 28,
#   'amount': 69.81808232696119,
#   'risk_score': 0.21049981667418163,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 34,
#   'borrower_id': 16,
#   'amount': 670.5998682754636,
#   'risk_score': 0.09274594049160932,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 35,
#   'borrower_id': 15,
#   'amount': 365.6988940873535,
#   'risk_score': 0.16315945151743974,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 36,
#   'borrower_id': 47,
#   'amount': 565.3547039333992,
#   'risk_score': 0.06577753729487244,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 37,
#   'borrower_id': 44,
#   'amount': 518.6130044446096,
#   'risk_score': 0.15010566058163563,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 38,
#   'borrower_id': 3,
#   'amount': 127.45016507480535,
#   'risk_score': 0.07171531307422917,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 39,
#   'borrower_id': 37,
#   'amount': 433.0982930676402,
#   'risk_score': 0.16528970095542556,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 40,
#   'borrower_id': 7,
#   'amount': 259.5330686762071,
#   'risk_score': 0.08731065323266118,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 41,
#   'borrower_id': 21,
#   'amount': 447.4797992342701,
#   'risk_score': 0.09674263533520072,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': 'None of the above choices                                                             '},
#  {'event_id': 42,
#   'borrower_id': 9,
#   'amount': 243.39936632513056,
#   'risk_score': 0.20441268653041084,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 26.0, 'sum_amount': 3253.152871382157, 'avg_amount': 125.12126428392912, 'max_amount': 161.8749143904734, 'min_amount': 115.91398822960586, 'prior_open_default': 0.0"},
#  {'event_id': 43,
#   'borrower_id': 39,
#   'amount': 848.4297859630868,
#   'risk_score': 0.08288878427458314,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 44,
#   'borrower_id': 18,
#   'amount': 215.48366974934092,
#   'risk_score': 0.2239260391943446,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': 'None of the above choices                                                             '},
#  {'event_id': 45,
#   'borrower_id': 4,
#   'amount': 962.741523912628,
#   'risk_score': 0.12321318807145919,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': 'None of the above choices                                                             '},
#  {'event_id': 46,
#   'borrower_id': 25,
#   'amount': 445.11199783959376,
#   'risk_score': 0.25778765235851514,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 47,
#   'borrower_id': 14,
#   'amount': 853.9330274180968,
#   'risk_score': 0.31074903744747145,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 30.0, 'sum_amount': 3733.0540753018327, 'avg_amount': 124.43513584339442, 'max_amount': 149.752210833546, 'min_amount': 113.0872504950358, 'prior_open_default': 1.0"},
#  {'event_id': 48,
#   'borrower_id': 50,
#   'amount': 647.3265772956479,
#   'risk_score': 0.12122049826747999,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': 'None of the above choices                                                             '},
#  {'event_id': 49,
#   'borrower_id': 9,
#   'amount': 748.582783732465,
#   'risk_score': 0.20441268653041084,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 26.0, 'sum_amount': 3253.152871382157, 'avg_amount': 125.12126428392912, 'max_amount': 161.8749143904734, 'min_amount': 115.91398822960586, 'prior_open_default': 0.0"},
#  {'event_id': 50,
#   'borrower_id': 26,
#   'amount': 779.3376936634412,
#   'risk_score': 0.13291662106147017,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 49.0, sum_amount': 2799.0165334790627, avg_amount': 57.12278639753189, max_amount': 86.13759532481636, min_amount': 35.10515010866272, prior_open_default': 1.0"},
#  {'event_id': 51,
#   'borrower_id': 2,
#   'amount': 529.6026377983669,
#   'risk_score': 0.09594517853251398,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 39.0, sum_amount': 4932.923543227153, avg_amount': 126.48521905710648, max_amount': 173.53725419764044, min_amount': 113.86568760315576, prior_open_default': 0.096"},
#  {'event_id': 52,
#   'borrower_id': 20,
#   'amount': 566.135497195124,
#   'risk_score': 0.24780195718315798,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 53,
#   'borrower_id': 28,
#   'amount': 538.2960744182888,
#   'risk_score': 0.21049981667418163,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 54,
#   'borrower_id': 47,
#   'amount': 608.6554591855753,
#   'risk_score': 0.06577753729487244,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 55,
#   'borrower_id': 7,
#   'amount': 77.92472346868193,
#   'risk_score': 0.08731065323266118,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 56,
#   'borrower_id': 44,
#   'amount': 425.73941135656446,
#   'risk_score': 0.15010566058163563,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 57,
#   'borrower_id': 8,
#   'amount': 625.879277883113,
#   'risk_score': 0.10438587777978468,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 58,
#   'borrower_id': 47,
#   'amount': 617.8373869930712,
#   'risk_score': 0.06577753729487244,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 59,
#   'borrower_id': 35,
#   'amount': 803.3082898753499,
#   'risk_score': 0.06554678230102151,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': 'None of the above choices                                                             '},
#  {'event_id': 60,
#   'borrower_id': 14,
#   'amount': 672.2588718905031,
#   'risk_score': 0.31074903744747145,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 30.0, 'sum_amount': 3733.0540753018327, 'avg_amount': 124.43513584339442, 'max_amount': 149.752210833546, 'min_amount': 113.0872504950358, 'prior_open_default': 1.0"},
#  {'event_id': 61,
#   'borrower_id': 17,
#   'amount': 992.5266505236388,
#   'risk_score': 0.40990682724104444,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': 'None of the above choices                                                             '},
#  {'event_id': 62,
#   'borrower_id': 36,
#   'amount': 319.6618021782128,
#   'risk_score': 0.14905862430447472,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 31.0, 'sum_amount': 3158.768529556319, 'avg_amount': 101.89575901794578, 'max_amount': 147.1144725785561, 'min_amount': 72.31018049557471, 'prior_open_default': 0.0"},
#  {'event_id': 63,
#   'borrower_id': 50,
#   'amount': 391.1934781829199,
#   'risk_score': 0.12122049826747999,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': 'None of the above choices                                                             '},
#  {'event_id': 64,
#   'borrower_id': 40,
#   'amount': 414.65479427440647,
#   'risk_score': 0.08666734902384388,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 65,
#   'borrower_id': 4,
#   'amount': 492.52216666923607,
#   'risk_score': 0.12321318807145919,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': 'None of the above choices                                                             '},
#  {'event_id': 66,
#   'borrower_id': 2,
#   'amount': 844.198160592149,
#   'risk_score': 0.09594517853251398,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 39.0, sum_amount': 4932.923543227153, avg_amount': 126.48521905710648, max_amount': 173.53725419764044, min_amount': 113.86568760315576, prior_open_default': 0.096"},
#  {'event_id': 67,
#   'borrower_id': 6,
#   'amount': 274.00248926124937,
#   'risk_score': 0.20299300453106908,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 27.0, 'sum_amount': 2801.997007878172, 'avg_amount': 103.7776669584508, 'max_amount': 131.75569392397895, 'min_amount': 81.46676613619405, 'prior_open_default': 0.0"},
#  {'event_id': 68,
#   'borrower_id': 42,
#   'amount': 787.200196683658,
#   'risk_score': 0.08054099364550482,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 69,
#   'borrower_id': 4,
#   'amount': 435.04467393145626,
#   'risk_score': 0.12321318807145919,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': 'None of the above choices                                                             '},
#  {'event_id': 70,
#   'borrower_id': 29,
#   'amount': 621.7626144789081,
#   'risk_score': 0.07791374846605766,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 71,
#   'borrower_id': 18,
#   'amount': 650.9135065649908,
#   'risk_score': 0.2239260391943446,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': 'None of the above choices                                                             '},
#  {'event_id': 72,
#   'borrower_id': 26,
#   'amount': 404.2062053294877,
#   'risk_score': 0.13291662106147017,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 49.0, sum_amount': 2799.0165334790627, avg_amount': 57.12278639753189, max_amount': 86.13759532481636, min_amount': 35.10515010866272, prior_open_default': 1.0"},
#  {'event_id': 73,
#   'borrower_id': 44,
#   'amount': 536.984444945515,
#   'risk_score': 0.15010566058163563,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 74,
#   'borrower_id': 34,
#   'amount': 442.3796159153122,
#   'risk_score': 0.09198366433383912,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 75,
#   'borrower_id': 10,
#   'amount': 115.67614687728847,
#   'risk_score': 0.0850644672502506,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 76,
#   'borrower_id': 36,
#   'amount': 465.3071193759852,
#   'risk_score': 0.14905862430447472,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 31.0, 'sum_amount': 3158.768529556319, 'avg_amount': 101.89575901794578, 'max_amount': 147.1144725785561, 'min_amount': 72.31018049557471, 'prior_open_default': 0.0"},
#  {'event_id': 77,
#   'borrower_id': 14,
#   'amount': 142.52372292587455,
#   'risk_score': 0.31074903744747145,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 30.0, 'sum_amount': 3733.0540753018327, 'avg_amount': 124.43513584339442, 'max_amount': 149.752210833546, 'min_amount': 113.0872504950358, 'prior_open_default': 1.0"},
#  {'event_id': 78,
#   'borrower_id': 31,
#   'amount': 434.7697591263054,
#   'risk_score': 0.4272692976326896,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 20.0, 3281.775897621598, avg_amount: 164.08879488107988, 'max_amount': 195.6824385331468, 'min_amount': 157.067461722762, 'prior_open_default': 1.0"},
#  {'event_id': 79,
#   'borrower_id': 48,
#   'amount': 613.2724798401928,
#   'risk_score': 0.16756151058708174,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 34.0, 'sum_amount': 1795.3696163552206, 'avg_amount': 52.804988716330016, 'max_amount': 52.804988716330016, 'max_amount': 73.69027869171543, 'min_amount': 39.08833903403678, 'prior_open_default': 0.0"},
#  {'event_id': 80,
#   'borrower_id': 15,
#   'amount': 600.4441543763257,
#   'risk_score': 0.16315945151743974,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 81,
#   'borrower_id': 8,
#   'amount': 679.4902150579044,
#   'risk_score': 0.10438587777978468,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 82,
#   'borrower_id': 14,
#   'amount': 140.49843255689495,
#   'risk_score': 0.31074903744747145,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 30.0, 'sum_amount': 3733.0540753018327, 'avg_amount': 124.43513584339442, 'max_amount': 149.752210833546, 'min_amount': 113.0872504950358, 'prior_open_default': 1.0"},
#  {'event_id': 83,
#   'borrower_id': 23,
#   'amount': 669.517083253916,
#   'risk_score': 0.2582170183590636,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 21.0, 'sum_amount': 3270.801311279966, 'avg_amount': 155.7524433942841, 'max_amount': 183.3259034689149, 'min_amount': 149.9261750717704, 'prior_open_default': 0.0"},
#  {'event_id': 84,
#   'borrower_id': 40,
#   'amount': 346.5406538616247,
#   'risk_score': 0.08666734902384388,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 85,
#   'borrower_id': 21,
#   'amount': 429.0936488302555,
#   'risk_score': 0.09674263533520072,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': 'None of the above choices                                                             '},
#  {'event_id': 86,
#   'borrower_id': 16,
#   'amount': 865.0869412265705,
#   'risk_score': 0.09274594049160932,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 87,
#   'borrower_id': 45,
#   'amount': 58.57888392307274,
#   'risk_score': 0.16648836570499215,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 34.0, 'sum_amount': 2579.5260727022787, 'avg_amount': 75.8684139030082, 'max_amount': 90.75193209103514, 'min_amount': 65.3623877138695, 'prior_open_default': 0.0"},
#  {'event_id': 88,
#   'borrower_id': 18,
#   'amount': 608.9920016735751,
#   'risk_score': 0.2239260391943446,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': 'None of the above choices                                                             '},
#  {'event_id': 89,
#   'borrower_id': 47,
#   'amount': 618.7782810951022,
#   'risk_score': 0.06577753729487244,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 90,
#   'borrower_id': 24,
#   'amount': 426.8267875263839,
#   'risk_score': 0.20904650199164818,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 91,
#   'borrower_id': 26,
#   'amount': 275.17646425291935,
#   'risk_score': 0.13291662106147017,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 49.0, sum_amount': 2799.0165334790627, avg_amount': 57.12278639753189, max_amount': 86.13759532481636, min_amount': 35.10515010866272, prior_open_default': 1.0"},
#  {'event_id': 92,
#   'borrower_id': 25,
#   'amount': 272.9403363484735,
#   'risk_score': 0.25778765235851514,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 93,
#   'borrower_id': 45,
#   'amount': 889.5241861777149,
#   'risk_score': 0.16648836570499215,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 34.0, 'sum_amount': 2579.5260727022787, 'avg_amount': 75.8684139030082, 'max_amount': 90.75193209103514, 'min_amount': 65.3623877138695, 'prior_open_default': 0.0"},
#  {'event_id': 94,
#   'borrower_id': 41,
#   'amount': 469.9231550937146,
#   'risk_score': 0.2058557694995223,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': 'None of the above choices                                                             '},
#  {'event_id': 95,
#   'borrower_id': 29,
#   'amount': 364.3448948397133,
#   'risk_score': 0.07791374846605766,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 96,
#   'borrower_id': 15,
#   'amount': 476.3386951398329,
#   'risk_score': 0.16315945151743974,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 97,
#   'borrower_id': 45,
#   'amount': 685.9208813863933,
#   'risk_score': 0.16648836570499215,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 34.0, 'sum_amount': 2579.5260727022787, 'avg_amount': 75.8684139030082, 'max_amount': 90.75193209103514, 'min_amount': 65.3623877138695, 'prior_open_default': 0.0"},
#  {'event_id': 98,
#   'borrower_id': 1,
#   'amount': 188.4687398325141,
#   'risk_score': 0.21510823516951177,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 26.0, 'sum_amount': 2529.847965068651, 'avg_amount': 97.30184481033272, 'max_amount': 131.54024380157318, 'min_amount': 83.4876234019785, 'prior_open_default': 0.0"},
#  {'event_id': 99,
#   'borrower_id': 25,
#   'amount': 476.9621434530508,
#   'risk_score': 0.25778765235851514,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 100,
#   'borrower_id': 7,
#   'amount': 608.4901525548676,
#   'risk_score': 0.08731065323266118,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 101,
#   'borrower_id': 9,
#   'amount': 951.154187108862,
#   'risk_score': 0.20441268653041084,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 26.0, 'sum_amount': 3253.152871382157, 'avg_amount': 125.12126428392912, 'max_amount': 161.8749143904734, 'min_amount': 115.91398822960586, 'prior_open_default': 0.0"},
#  {'event_id': 102,
#   'borrower_id': 24,
#   'amount': 289.9013929716483,
#   'risk_score': 0.20904650199164818,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 103,
#   'borrower_id': 1,
#   'amount': 391.28821052043327,
#   'risk_score': 0.21510823516951177,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 26.0, 'sum_amount': 2529.847965068651, 'avg_amount': 97.30184481033272, 'max_amount': 131.54024380157318, 'min_amount': 83.4876234019785, 'prior_open_default': 0.0"},
#  {'event_id': 104,
#   'borrower_id': 44,
#   'amount': 410.3906604263026,
#   'risk_score': 0.15010566058163563,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 105,
#   'borrower_id': 8,
#   'amount': 625.2612497626387,
#   'risk_score': 0.10438587777978468,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 106,
#   'borrower_id': 24,
#   'amount': 388.8954503880016,
#   'risk_score': 0.20904650199164818,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 107,
#   'borrower_id': 11,
#   'amount': 556.8363290347108,
#   'risk_score': 0.24262931599339552,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 108,
#   'borrower_id': 17,
#   'amount': 792.7008133527779,
#   'risk_score': 0.40990682724104444,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': 'None of the above choices                                                             '},
#  {'event_id': 109,
#   'borrower_id': 8,
#   'amount': 720.1163144065935,
#   'risk_score': 0.10438587777978468,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 110,
#   'borrower_id': 35,
#   'amount': 474.0502141869563,
#   'risk_score': 0.06554678230102151,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': 'None of the above choices                                                             '},
#  {'event_id': 111,
#   'borrower_id': 35,
#   'amount': 871.0053687904605,
#   'risk_score': 0.06554678230102151,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': 'None of the above choices                                                             '},
#  {'event_id': 112,
#   'borrower_id': 33,
#   'amount': 580.2332371141697,
#   'risk_score': 0.07125389103387866,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 113,
#   'borrower_id': 5,
#   'amount': 562.9105475271018,
#   'risk_score': 0.15733728274475772,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 30.0, 'sum_amount': 3721.230154351119, 'avg_amount': 124.0410051450373, 'max_amount': 168.0425482566293, 'min_amount': 106.92025586106271, 'prior_open_default': 0.0"},
#  {'event_id': 114,
#   'borrower_id': 42,
#   'amount': 82.47837764220026,
#   'risk_score': 0.08054099364550482,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 115,
#   'borrower_id': 39,
#   'amount': 987.3583313393036,
#   'risk_score': 0.08288878427458314,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 116,
#   'borrower_id': 41,
#   'amount': 166.82226810314538,
#   'risk_score': 0.2058557694995223,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': 'None of the above choices                                                             '},
#  {'event_id': 117,
#   'borrower_id': 28,
#   'amount': 269.57436680626427,
#   'risk_score': 0.21049981667418163,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 118,
#   'borrower_id': 7,
#   'amount': 99.1119953794506,
#   'risk_score': 0.08731065323266118,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 119,
#   'borrower_id': 9,
#   'amount': 658.002818495068,
#   'risk_score': 0.20441268653041084,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 26.0, 'sum_amount': 3253.152871382157, 'avg_amount': 125.12126428392912, 'max_amount': 161.8749143904734, 'min_amount': 115.91398822960586, 'prior_open_default': 0.0"},
#  {'event_id': 120,
#   'borrower_id': 8,
#   'amount': 263.46611812404603,
#   'risk_score': 0.10438587777978468,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 121,
#   'borrower_id': 12,
#   'amount': 221.0099155990873,
#   'risk_score': 0.1102468853321185,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 122,
#   'borrower_id': 34,
#   'amount': 134.1278050120793,
#   'risk_score': 0.09198366433383912,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 123,
#   'borrower_id': 33,
#   'amount': 148.14350926781486,
#   'risk_score': 0.07125389103387866,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 124,
#   'borrower_id': 48,
#   'amount': 605.4371654204593,
#   'risk_score': 0.16756151058708174,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 34.0, 'sum_amount': 1795.3696163552206, 'avg_amount': 52.804988716330016, 'max_amount': 52.804988716330016, 'max_amount': 73.69027869171543, 'min_amount': 39.08833903403678, 'prior_open_default': 0.0"},
#  {'event_id': 125,
#   'borrower_id': 23,
#   'amount': 703.7974725732656,
#   'risk_score': 0.2582170183590636,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 21.0, 'sum_amount': 3270.801311279966, 'avg_amount': 155.7524433942841, 'max_amount': 183.3259034689149, 'min_amount': 149.9261750717704, 'prior_open_default': 0.0"},
#  {'event_id': 126,
#   'borrower_id': 24,
#   'amount': 427.51003904118096,
#   'risk_score': 0.20904650199164818,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 127,
#   'borrower_id': 37,
#   'amount': 505.9022275124696,
#   'risk_score': 0.16528970095542556,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 128,
#   'borrower_id': 35,
#   'amount': 701.6693491838349,
#   'risk_score': 0.06554678230102151,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': 'None of the above choices                                                             '},
#  {'event_id': 129,
#   'borrower_id': 44,
#   'amount': 66.51080067620566,
#   'risk_score': 0.15010566058163563,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 130,
#   'borrower_id': 40,
#   'amount': 356.9741242167646,
#   'risk_score': 0.08666734902384388,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 131,
#   'borrower_id': 22,
#   'amount': 974.4428606668292,
#   'risk_score': 0.23561546304175604,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 132,
#   'borrower_id': 27,
#   'amount': 601.1066182106947,
#   'risk_score': 0.22204469012756772,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 133,
#   'borrower_id': 35,
#   'amount': 291.5133509026186,
#   'risk_score': 0.06554678230102151,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': 'None of the above choices                                                             '},
#  {'event_id': 134,
#   'borrower_id': 1,
#   'amount': 545.6435443044024,
#   'risk_score': 0.21510823516951177,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 26.0, 'sum_amount': 2529.847965068651, 'avg_amount': 97.30184481033272, 'max_amount': 131.54024380157318, 'min_amount': 83.4876234019785, 'prior_open_default': 0.0"},
#  {'event_id': 135,
#   'borrower_id': 35,
#   'amount': 375.5208137148696,
#   'risk_score': 0.06554678230102151,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': 'None of the above choices                                                             '},
#  {'event_id': 136,
#   'borrower_id': 37,
#   'amount': 555.6327393849842,
#   'risk_score': 0.16528970095542556,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 137,
#   'borrower_id': 47,
#   'amount': 169.4544362163164,
#   'risk_score': 0.06577753729487244,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 138,
#   'borrower_id': 14,
#   'amount': 176.0789211283135,
#   'risk_score': 0.31074903744747145,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 30.0, 'sum_amount': 3733.0540753018327, 'avg_amount': 124.43513584339442, 'max_amount': 149.752210833546, 'min_amount': 113.0872504950358, 'prior_open_default': 1.0"},
#  {'event_id': 139,
#   'borrower_id': 3,
#   'amount': 186.3652439374232,
#   'risk_score': 0.07171531307422917,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 140,
#   'borrower_id': 1,
#   'amount': 942.8288023304996,
#   'risk_score': 0.21510823516951177,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 26.0, 'sum_amount': 2529.847965068651, 'avg_amount': 97.30184481033272, 'max_amount': 131.54024380157318, 'min_amount': 83.4876234019785, 'prior_open_default': 0.0"},
#  {'event_id': 141,
#   'borrower_id': 5,
#   'amount': 746.2539724242747,
#   'risk_score': 0.15733728274475772,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 30.0, 'sum_amount': 3721.230154351119, 'avg_amount': 124.0410051450373, 'max_amount': 168.0425482566293, 'min_amount': 106.92025586106271, 'prior_open_default': 0.0"},
#  {'event_id': 142,
#   'borrower_id': 26,
#   'amount': 204.26279992920485,
#   'risk_score': 0.13291662106147017,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 49.0, sum_amount': 2799.0165334790627, avg_amount': 57.12278639753189, max_amount': 86.13759532481636, min_amount': 35.10515010866272, prior_open_default': 1.0"},
#  {'event_id': 143,
#   'borrower_id': 14,
#   'amount': 228.93162957732136,
#   'risk_score': 0.31074903744747145,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 30.0, 'sum_amount': 3733.0540753018327, 'avg_amount': 124.43513584339442, 'max_amount': 149.752210833546, 'min_amount': 113.0872504950358, 'prior_open_default': 1.0"},
#  {'event_id': 144,
#   'borrower_id': 39,
#   'amount': 744.2880011273326,
#   'risk_score': 0.08288878427458314,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 145,
#   'borrower_id': 27,
#   'amount': 198.35565255256523,
#   'risk_score': 0.22204469012756772,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 146,
#   'borrower_id': 9,
#   'amount': 272.83322866808726,
#   'risk_score': 0.20441268653041084,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 26.0, 'sum_amount': 3253.152871382157, 'avg_amount': 125.12126428392912, 'max_amount': 161.8749143904734, 'min_amount': 115.91398822960586, 'prior_open_default': 0.0"},
#  {'event_id': 147,
#   'borrower_id': 15,
#   'amount': 965.179491179379,
#   'risk_score': 0.16315945151743974,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 148,
#   'borrower_id': 15,
#   'amount': 292.54119849201027,
#   'risk_score': 0.16315945151743974,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 149,
#   'borrower_id': 26,
#   'amount': 678.5507328525895,
#   'risk_score': 0.13291662106147017,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 49.0, sum_amount': 2799.0165334790627, avg_amount': 57.12278639753189, max_amount': 86.13759532481636, min_amount': 35.10515010866272, prior_open_default': 1.0"},
#  {'event_id': 150,
#   'borrower_id': 42,
#   'amount': 979.6997230305038,
#   'risk_score': 0.08054099364550482,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 151,
#   'borrower_id': 13,
#   'amount': 405.581928782803,
#   'risk_score': 0.19356899482731646,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 152,
#   'borrower_id': 32,
#   'amount': 66.64019131895913,
#   'risk_score': 0.317230707084168,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': 'None of the above choices                                                             '},
#  {'event_id': 153,
#   'borrower_id': 39,
#   'amount': 281.93992590125555,
#   'risk_score': 0.08288878427458314,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 154,
#   'borrower_id': 49,
#   'amount': 839.3333317746202,
#   'risk_score': 0.06533639659489342,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 155,
#   'borrower_id': 32,
#   'amount': 871.3783941572849,
#   'risk_score': 0.317230707084168,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': 'None of the above choices                                                             '},
#  {'event_id': 156,
#   'borrower_id': 4,
#   'amount': 780.0933962976017,
#   'risk_score': 0.12321318807145919,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': 'None of the above choices                                                             '},
#  {'event_id': 157,
#   'borrower_id': 30,
#   'amount': 157.45432812274436,
#   'risk_score': 0.11010876257857698,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 158,
#   'borrower_id': 37,
#   'amount': 805.734853111583,
#   'risk_score': 0.16528970095542556,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 159,
#   'borrower_id': 23,
#   'amount': 922.743907143829,
#   'risk_score': 0.2582170183590636,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 21.0, 'sum_amount': 3270.801311279966, 'avg_amount': 155.7524433942841, 'max_amount': 183.3259034689149, 'min_amount': 149.9261750717704, 'prior_open_default': 0.0"},
#  {'event_id': 160,
#   'borrower_id': 39,
#   'amount': 620.5790654189243,
#   'risk_score': 0.08288878427458314,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 161,
#   'borrower_id': 45,
#   'amount': 943.8315885211616,
#   'risk_score': 0.16648836570499215,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 34.0, 'sum_amount': 2579.5260727022787, 'avg_amount': 75.8684139030082, 'max_amount': 90.75193209103514, 'min_amount': 65.3623877138695, 'prior_open_default': 0.0"},
#  {'event_id': 162,
#   'borrower_id': 15,
#   'amount': 835.4969395262835,
#   'risk_score': 0.16315945151743974,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 163,
#   'borrower_id': 43,
#   'amount': 683.6229411413619,
#   'risk_score': 0.07371093251209905,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': 'None of the above choices                                                             '},
#  {'event_id': 164,
#   'borrower_id': 29,
#   'amount': 598.3259748761608,
#   'risk_score': 0.07791374846605766,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 165,
#   'borrower_id': 36,
#   'amount': 381.144983879872,
#   'risk_score': 0.14905862430447472,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 31.0, 'sum_amount': 3158.768529556319, 'avg_amount': 101.89575901794578, 'max_amount': 147.1144725785561, 'min_amount': 72.31018049557471, 'prior_open_default': 0.0"},
#  {'event_id': 166,
#   'borrower_id': 13,
#   'amount': 201.32307298066488,
#   'risk_score': 0.19356899482731646,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 167,
#   'borrower_id': 32,
#   'amount': 624.7062265560138,
#   'risk_score': 0.317230707084168,
# ...
#  {'event_id': 447,
#   'borrower_id': 32,
#   'amount': 177.11354946551427,
#   'risk_score': 0.317230707084168,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': 'None of the above choices                                                             '},
#  {'event_id': 448,
#   'borrower_id': 30,
#   'amount': 447.6515905427385,
#   'risk_score': 0.11010876257857698,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 449,
#   'borrower_id': 47,
#   'amount': 800.8208490671407,
#   'risk_score': 0.06577753729487244,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 450,
#   'borrower_id': 35,
#   'amount': 603.0408182909737,
#   'risk_score': 0.06554678230102151,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': 'None of the above choices                                                             '},
#  {'event_id': 451,
#   'borrower_id': 40,
#   'amount': 696.9260858763323,
#   'risk_score': 0.08666734902384388,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 452,
#   'borrower_id': 16,
#   'amount': 230.21010576594333,
#   'risk_score': 0.09274594049160932,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 453,
#   'borrower_id': 13,
#   'amount': 638.0007833573354,
#   'risk_score': 0.19356899482731646,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 454,
#   'borrower_id': 50,
#   'amount': 357.3253751659001,
#   'risk_score': 0.12122049826747999,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': 'None of the above choices                                                             '},
#  {'event_id': 455,
#   'borrower_id': 42,
#   'amount': 842.5881976570291,
#   'risk_score': 0.08054099364550482,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 456,
#   'borrower_id': 30,
#   'amount': 647.8338657101993,
#   'risk_score': 0.11010876257857698,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 457,
#   'borrower_id': 19,
#   'amount': 238.9134638865311,
#   'risk_score': 0.10068270906657707,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 458,
#   'borrower_id': 17,
#   'amount': 111.38584585188184,
#   'risk_score': 0.40990682724104444,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': 'None of the above choices                                                             '},
#  {'event_id': 459,
#   'borrower_id': 19,
#   'amount': 90.5015488226811,
#   'risk_score': 0.10068270906657707,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 460,
#   'borrower_id': 28,
#   'amount': 402.8381392676337,
#   'risk_score': 0.21049981667418163,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 461,
#   'borrower_id': 26,
#   'amount': 302.55857982159785,
#   'risk_score': 0.13291662106147017,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 49.0, sum_amount': 2799.0165334790627, avg_amount': 57.12278639753189, max_amount': 86.13759532481636, min_amount': 35.10515010866272, prior_open_default': 1.0"},
#  {'event_id': 462,
#   'borrower_id': 37,
#   'amount': 663.7856172893827,
#   'risk_score': 0.16528970095542556,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 463,
#   'borrower_id': 26,
#   'amount': 524.3671432296874,
#   'risk_score': 0.13291662106147017,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 49.0, sum_amount': 2799.0165334790627, avg_amount': 57.12278639753189, max_amount': 86.13759532481636, min_amount': 35.10515010866272, prior_open_default': 1.0"},
#  {'event_id': 464,
#   'borrower_id': 23,
#   'amount': 302.7183141051117,
#   'risk_score': 0.2582170183590636,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 21.0, 'sum_amount': 3270.801311279966, 'avg_amount': 155.7524433942841, 'max_amount': 183.3259034689149, 'min_amount': 149.9261750717704, 'prior_open_default': 0.0"},
#  {'event_id': 465,
#   'borrower_id': 9,
#   'amount': 191.7758890526673,
#   'risk_score': 0.20441268653041084,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 26.0, 'sum_amount': 3253.152871382157, 'avg_amount': 125.12126428392912, 'max_amount': 161.8749143904734, 'min_amount': 115.91398822960586, 'prior_open_default': 0.0"},
#  {'event_id': 466,
#   'borrower_id': 12,
#   'amount': 170.83977455307712,
#   'risk_score': 0.1102468853321185,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 467,
#   'borrower_id': 1,
#   'amount': 871.4273725333968,
#   'risk_score': 0.21510823516951177,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 26.0, 'sum_amount': 2529.847965068651, 'avg_amount': 97.30184481033272, 'max_amount': 131.54024380157318, 'min_amount': 83.4876234019785, 'prior_open_default': 0.0"},
#  {'event_id': 468,
#   'borrower_id': 1,
#   'amount': 281.3040699846239,
#   'risk_score': 0.21510823516951177,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 26.0, 'sum_amount': 2529.847965068651, 'avg_amount': 97.30184481033272, 'max_amount': 131.54024380157318, 'min_amount': 83.4876234019785, 'prior_open_default': 0.0"},
#  {'event_id': 469,
#   'borrower_id': 47,
#   'amount': 669.1251155154199,
#   'risk_score': 0.06577753729487244,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 470,
#   'borrower_id': 34,
#   'amount': 820.1516315869529,
#   'risk_score': 0.09198366433383912,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 471,
#   'borrower_id': 32,
#   'amount': 633.3772456254993,
#   'risk_score': 0.317230707084168,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': 'None of the above choices                                                             '},
#  {'event_id': 472,
#   'borrower_id': 48,
#   'amount': 866.5869700645985,
#   'risk_score': 0.16756151058708174,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 34.0, 'sum_amount': 1795.3696163552206, 'avg_amount': 52.804988716330016, 'max_amount': 52.804988716330016, 'max_amount': 73.69027869171543, 'min_amount': 39.08833903403678, 'prior_open_default': 0.0"},
#  {'event_id': 473,
#   'borrower_id': 25,
#   'amount': 422.7740354520508,
#   'risk_score': 0.25778765235851514,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 474,
#   'borrower_id': 40,
#   'amount': 958.4110811165008,
#   'risk_score': 0.08666734902384388,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 475,
#   'borrower_id': 45,
#   'amount': 176.48775396919208,
#   'risk_score': 0.16648836570499215,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 34.0, 'sum_amount': 2579.5260727022787, 'avg_amount': 75.8684139030082, 'max_amount': 90.75193209103514, 'min_amount': 65.3623877138695, 'prior_open_default': 0.0"},
#  {'event_id': 476,
#   'borrower_id': 1,
#   'amount': 147.0420531746612,
#   'risk_score': 0.21510823516951177,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 26.0, 'sum_amount': 2529.847965068651, 'avg_amount': 97.30184481033272, 'max_amount': 131.54024380157318, 'min_amount': 83.4876234019785, 'prior_open_default': 0.0"},
#  {'event_id': 477,
#   'borrower_id': 16,
#   'amount': 675.7575388970714,
#   'risk_score': 0.09274594049160932,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 478,
#   'borrower_id': 39,
#   'amount': 945.6895843425988,
#   'risk_score': 0.08288878427458314,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 479,
#   'borrower_id': 5,
#   'amount': 818.4392885545117,
#   'risk_score': 0.15733728274475772,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 30.0, 'sum_amount': 3721.230154351119, 'avg_amount': 124.0410051450373, 'max_amount': 168.0425482566293, 'min_amount': 106.92025586106271, 'prior_open_default': 0.0"},
#  {'event_id': 480,
#   'borrower_id': 22,
#   'amount': 122.59601646614884,
#   'risk_score': 0.23561546304175604,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 481,
#   'borrower_id': 29,
#   'amount': 315.39932823798057,
#   'risk_score': 0.07791374846605766,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 482,
#   'borrower_id': 3,
#   'amount': 933.8029405959325,
#   'risk_score': 0.07171531307422917,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 483,
#   'borrower_id': 12,
#   'amount': 290.40551116074533,
#   'risk_score': 0.1102468853321185,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 484,
#   'borrower_id': 26,
#   'amount': 792.1119025975732,
#   'risk_score': 0.13291662106147017,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 49.0, sum_amount': 2799.0165334790627, avg_amount': 57.12278639753189, max_amount': 86.13759532481636, min_amount': 35.10515010866272, prior_open_default': 1.0"},
#  {'event_id': 485,
#   'borrower_id': 16,
#   'amount': 833.8755861322686,
#   'risk_score': 0.09274594049160932,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 486,
#   'borrower_id': 37,
#   'amount': 520.6794982879327,
#   'risk_score': 0.16528970095542556,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 487,
#   'borrower_id': 22,
#   'amount': 417.0314643558997,
#   'risk_score': 0.23561546304175604,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 488,
#   'borrower_id': 29,
#   'amount': 477.61821079877166,
#   'risk_score': 0.07791374846605766,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 489,
#   'borrower_id': 14,
#   'amount': 265.61645964709595,
#   'risk_score': 0.31074903744747145,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 30.0, 'sum_amount': 3733.0540753018327, 'avg_amount': 124.43513584339442, 'max_amount': 149.752210833546, 'min_amount': 113.0872504950358, 'prior_open_default': 1.0"},
#  {'event_id': 490,
#   'borrower_id': 28,
#   'amount': 894.921370322402,
#   'risk_score': 0.21049981667418163,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 491,
#   'borrower_id': 5,
#   'amount': 478.08867389327,
#   'risk_score': 0.15733728274475772,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 30.0, 'sum_amount': 3721.230154351119, 'avg_amount': 124.0410051450373, 'max_amount': 168.0425482566293, 'min_amount': 106.92025586106271, 'prior_open_default': 0.0"},
#  {'event_id': 492,
#   'borrower_id': 47,
#   'amount': 888.3364684332948,
#   'risk_score': 0.06577753729487244,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 493,
#   'borrower_id': 49,
#   'amount': 150.40880591096038,
#   'risk_score': 0.06533639659489342,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 494,
#   'borrower_id': 30,
#   'amount': 988.8615074501248,
#   'risk_score': 0.11010876257857698,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 495,
#   'borrower_id': 46,
#   'amount': 471.10943307143737,
#   'risk_score': 0.07122148475523722,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 496,
#   'borrower_id': 5,
#   'amount': 95.4392793744002,
#   'risk_score': 0.15733728274475772,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 30.0, 'sum_amount': 3721.230154351119, 'avg_amount': 124.0410051450373, 'max_amount': 168.0425482566293, 'min_amount': 106.92025586106271, 'prior_open_default': 0.0"},
#  {'event_id': 497,
#   'borrower_id': 12,
#   'amount': 86.12075582558217,
#   'risk_score': 0.1102468853321185,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 498,
#   'borrower_id': 16,
#   'amount': 758.8968946077466,
#   'risk_score': 0.09274594049160932,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'FREEZE',
#   'reason': 'None of the above choices FREEZE, VERIFY, ALLOW, HUMAN_REVIEW'},
#  {'event_id': 499,
#   'borrower_id': 26,
#   'amount': 676.0837574934967,
#   'risk_score': 0.13291662106147017,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 49.0, sum_amount': 2799.0165334790627, avg_amount': 57.12278639753189, max_amount': 86.13759532481636, min_amount': 35.10515010866272, prior_open_default': 1.0"},
#  {'event_id': 500,
#   'borrower_id': 26,
#   'amount': 812.0240302212081,
#   'risk_score': 0.13291662106147017,
#   'retrieved_doc': 'Risk<0.3 → ALLOW',
#   'action': 'HUMAN_REVIEW',
#   'reason': "Context: Borrower features: 'count': 49.0, sum_amount': 2799.0165334790627, avg_amount': 57.12278639753189, max_amount': 86.13759532481636, min_amount': 35.10515010866272, prior_open_default': 1.0"}]
